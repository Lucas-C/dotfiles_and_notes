# %% [markdown]
# <style>
# .points {
#     color: green;
# }
# img[alt=img_choice] { max-width: 400px; max-height: 300px; }
# </style>
# # Wildlife Exam

# %% [markdown]
# ## Reptiles
# * What are the 2 reptiles found in the wild in Ireland ? *(Warning: the name must match the latin name)*
# A=<input name="q1_reptA_cname"/> : *Lacerta* <input name="q1_reptA_lname2"/> <span class="points">[2 points]</span>
# B=<input name="q1_reptB_cname"/> : *Anguis* <input name="q1_reptB_lname2"/> <span class="points">[2 points]</span>

# %% [markdown]
# ### Reptile A
#
# * List 2 differences between this reptile and the newt : <span class="points">[2 points]</span>
# <input name="q1_reptA_diffwithnewt_1"/>
# <input name="q1_reptA_diffwithnewt_2"/>
#
# * When is their mating period during the year ? <span class="points">[1 point]</span>
# <input name="q1_reptA_matingperiod"/>
#
# * Check which of the following are part of its feeding : <span class="points">[2 points]</span>
# <input type=checkbox name="q1_reptA_eat_wasp">Wasps<BR>
# <input type=checkbox name="q1_reptA_eat_centipedes">Centipedes<BR>
# <input type=checkbox name="q1_reptA_eat_bees">Bees<BR>
# <input type=checkbox name="q1_reptA_eat_ants">Ants<BR>
#
# * To what size can it grow ? <span class="points">[1 point]</span>
# <input name="q1_reptA_maxsize_cm"/> cm
#
# * Can their underside be orange ? <span class="points">[+/-1 point]</span>
# <input type=radio name="q1_reptA_orangeunderside" value="yes">Yes<BR>
# <input type=radio name="q1_reptA_orangeunderside" value="no">No<BR>
#
# * List 2 caracteristics of their habitat : <span class="points">[2 points]</span>
# <input name="q1_reptA_habitatcarac_1"/>
# <input name="q1_reptA_habitatcarac_2"/>
#
# * Identify reptile A among the following photos : <span class="points">[4 points]</span>
#
# <table><tr>
# <th><input type=radio name="q1_reptA_img_choice" value="A">![img_choice](https://upload.wikimedia.org/wikipedia/commons/f/f3/Lacerta_vivipara_1_%28Marek_Szczepanek%29.jpg "choice A")</th><th><input type=radio name="q1_reptA_img_choice" value="B">![img_choice](http://richard-seaman.com/Wallpaper/Nature/Reptiles/Lizards/SideBlotchedLizard.jpg "choice B")</th>
# </tr><tr>
# <th><input type=radio name="q1_reptA_img_choice" value="C">![img_choice](http://www.californiaherps.com/lizards/images/ecprincipis3dn.jpg "choice C")</th><th><input type=radio name="q1_reptA_img_choice" value="D">![img_choice](http://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Common_Lizard_on_Thursley_Common_2.JPG/800px-Common_Lizard_on_Thursley_Common_2.JPG "choice D")</th>
# </tr></table>

# %% [markdown]
# ### Reptile B
# * List 2 other countries where it can be found : <span class="points">[2 points]</span>
# <input name="q1_reptB_othercountry_1"/>
# <input name="q1_reptB_othercountry_2"/>
#
# * What is their period of frost-free hibernation ? <span class="points">[1 point]</span>
# <input name="q1_reptB_hibernation_period"/>
#
# * To what size can it grow ? <span class="points">[1 point]</span>
# <input name="q1_reptB_maxsize_cm"/> cm
#
# * Can they have a near-blue color ? <span class="points">[+/-1 point]</span>
# <input type=radio name="q1_reptB_color_blue" value="yes">Yes<BR>
# <input type=radio name="q1_reptB_color_blue" value="no">No<BR>
#
# * List 2 predators of this reptile : <span class="points">[2 points]</span>
# <input name="q1_reptB_predator_1"/>
# <input name="q1_reptB_predator_2"/>
#
# * List 2 preys for this reptile : <span class="points">[2 points]</span>
# <input name="q1_reptB_prey_1"/>
# <input name="q1_reptB_prey_2"/>
#
# * Identify reptile B among the following photos : <span class="points">[4 points]</span>
# <table><tr>
# <th><input type=radio name="q1_reptB_img_choice" value="A">![img_choice](http://lh4.ggpht.com/-RuNaqA9XmnY/SXfG_3MhwsI/AAAAAAAACuw/_8-Eqi9hiUw/DSC_0481.JPG "choice A")</input></th><th><input type=radio name="q1_reptB_img_choice" value="B">![img_choice](http://classconnection.s3.amazonaws.com/378/flashcards/1111378/jpg/family_anguidae_-_glass_and_alligator_lizards1349908824629.jpg "choice B")</input></th>
# </tr><tr>
# <th><input type=radio name="q1_reptB_img_choice" value="C">![img_choice](http://farm9.staticflickr.com/8153/7631455048_317620be9e_z.jpg "choice C")</input></th><th><input type=radio name="q1_reptB_img_choice" value="D">![img_choice](https://upload.wikimedia.org/wikipedia/commons/5/5e/Anguidae.jpg "choice D")</input></th>
# </tr></table>

# %% [markdown]
# ## The Red Squirrel
# * What is the scientific name of the Red Squirrel ? <span class="points">[1 point]</span>
# <input name="q2_squirrelred_latin_name"/>
#
# * What is the scientific name of the Grey Squirrel ? <span class="points">[1 point]</span>
# <input name="q2_squirrelgrey_latin_name"/>
#
#
# * Can the Red Squirrel be found in : <span class="points">[3 points]</span>
# <input type=checkbox name="q2_squirrelred_geoloc_Dublin">Dublin<BR>
# <input type=checkbox name="q2_squirrelred_geoloc_Galway">Galway<BR>
# <input type=checkbox name="q2_squirrelred_geoloc_Cork">Cork<BR>
#
# * Can the Grey Squirrel be found in : <span class="points">[3 points]</span>
# <input type=checkbox name="q2_squirrelgrey_geoloc_Dublin">Dublin<BR>
# <input type=checkbox name="q2_squirrelgrey_geoloc_Galway">Galway<BR>
# <input type=checkbox name="q2_squirrelgrey_geoloc_Cork">Cork<BR>
#
# * List 2 trees that the Red Squirrel eat the seeds : <span class="points">[2 points]</span>
# <input name="q2_squirrelred_eatseedsfromtree_A"/>
# <input name="q2_squirrelred_eatseedsfromtree_B"/>
#
# * What is the shape of its nest : <span class="points">[1 point]</span>
# <input type=radio name="q2_squirrelred_nestshape" value="cone">A cone</input>
# <input type=radio name="q2_squirrelred_nestshape" value="sphere">A sphere</input>
# <input type=radio name="q2_squirrelred_nestshape" value="half_sphere">Half of a sphere</input>
# <input type=radio name="q2_squirrelred_nestshape" value="tipi">A tipi</input>
#
# * When in the year is the red Squirrel mating period ? <span class="points">[1 point]</span>
# <input name="q2_squirrelred_mating_months"/>
#
# * How many young Red Squirrel survive to breeding age (1 year) ? <span class="points">[1 point]</span>
# <input type=radio name="q2_squirrelred_mortality_1year" value="5_15">5-15%</input>
# <input type=radio name="q2_squirrelred_mortality_1year" value="15_25">15-25%</input>
# <input type=radio name="q2_squirrelred_mortality_1year" value="25_35">25-35%</input>
# <input type=radio name="q2_squirrelred_mortality_1year" value="35_45">35-45%</input>
#
# * List 2 of its most common causes of death ? <span class="points">[2 points]</span>
# <input name="q2_squirrelred_deathcause_A"/>
# <input name="q2_squirrelred_deathcause_B"/>
#
# * How many Red Squirrels is there in Ireland : <span class="points">[1 point]</span>
# <input type=radio name="q2_squirrelred_irish_population" value="10_000">10 000</input>
# <input type=radio name="q2_squirrelred_irish_population" value="40_000">40 000</input>
# <input type=radio name="q2_squirrelred_irish_population" value="100_000">100 000</input>
# <input type=radio name="q2_squirrelred_irish_population" value="400_000">400 000</input>
#
# * When was the Grey Squirrel introduced in Ireland ? <span class="points">[2 points]</span>
# <input name="q2_squirrelgrey_introduction_date"/>
#
# * List 2 criteria on which the Grey Squirrel outcompete the Red Squirrel : <span class="points">[2 points]</span>
# <input name="q2_squirrelgrey_outcompete_squirrelred_A"/>
# <input name="q2_squirrelgrey_outcompete_squirrelred_B"/>
#
# * What is the name of the disease that affects Red Squirrels in Britain but to which Grey Squirrels are immune : <span class="points">[1 point]</span>
# <input name="q2_greysquirrel_squirrelred_disease"/>
#
# * Give the name of one species of tree very exposed to Grey Squirrel bark-stripping habit : <span class="points">[1 point]</span>
# <input name="q2_greysquirrel_barkstrip_tree"/>
#
# * Identify the Red Squirrel (R) qnd Grey Squirrel (G) in the following photos : <span class="points">[4 points]</span>
# <table><tr>
# <th><input type=radio name="q2_greysquirrel_img_choice" value="A">G</input><input type=radio name="q2_redsquirrel_img_choice" value="A">R</input>![img_choice](http://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Eastern_Grey_Squirrel_in_St_James%27s_Park%2C_London_-_Nov_2006_edit.jpg/777px-Eastern_Grey_Squirrel_in_St_James%27s_Park%2C_London_-_Nov_2006_edit.jpg "choice A")</th><th><input type=radio name="q2_greysquirrel_img_choice" value="B">G</input><input type=radio name="q2_redsquirrel_img_choice" value="B">R</input>![img_choice](http://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Indian_Palm_Squirrel_%28Funambulus_palmarum%29.jpg/293px-Indian_Palm_Squirrel_%28Funambulus_palmarum%29.jpg "choice B")</th>
# </tr><tr>
# <th><input type=radio name="q2_greysquirrel_img_choice" value="C">G</input><input type=radio name="q2_redsquirrel_img_choice" value="C">R</input>![img_choice](http://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Sciurus_granatensis_Humboldt_1811.jpg/505px-Sciurus_granatensis_Humboldt_1811.jpg "choice C")</th><th><input type=radio name="q2_greysquirrel_img_choice" value="D">G</input><input type=radio name="q2_redsquirrel_img_choice" value="D">R</input>![img_choice](http://upload.wikimedia.org/wikipedia/commons/thumb/9/95/Sciurus-vulgaris_hernandeangelis_stockholm_2008-06-04.jpg/800px-Sciurus-vulgaris_hernandeangelis_stockholm_2008-06-04.jpg "choice D")<th>
# </tr></table>

# %% [markdown]
# ## Bats
# * How many bats species is there in Ireland ? <span class="points">[1 point]</span>
# <input name="q3_bats_species_count"/>
#
# * List 4 of them : <span class="points">[4 points]</span>
# <input name="q3_bats_species_A"/>
# <input name="q3_bats_species_B"/>
# <input name="q3_bats_species_C"/>
# <input name="q3_bats_species_D"/>
#
# * What's the name of the mushroom-shaped flap in their ear ? <span class="points">[1 point]</span>
# <input name="q3_bats_earflap_name"/>
#
# * List 3 insects that the bats eat : <span class="points">[3 points]</span>
# <input name="q3_bats_eatinsect_A"/>
# <input name="q3_bats_eatinsect_B"/>
# <input name="q3_bats_eatinsect_C"/>
#
# * Up to how many insects can a pipistrelle eat in one night ? <span class="points">[1 point]</span>
# <input name="q3_bats_pipistrelle_onenightfeast"/>
#
# * List 2 extracts of the 1976 Wildlife Act relative to bats : <span class="points">[4 points]</span>
# <input name="q3_bats_1976wildlife_extractA"/>
# <input name="q3_bats_1976wildlife_extractB"/>
#
# * How many times a year does bats breed ? <span class="points">[1 point]</span>
# <input name="q3_bats_breedperyear"/>
#
# * How many baby bats is there in one litter ? <span class="points">[1 point]</span>
# <input name="q3_bats_babiesperlitter"/>
#
# * When in the year is their mating period ? <span class="points">[1 point]</span>
# <input name="q3_bats_mating_period"/>
#
# * Give an order of idea of a bat body temperature during winter ? <span class="points">[1 point]</span>
# <input name="q3_bats_body_temperature"/>

# %% [markdown]
# ## Amphibians
# * What are the 2 amphibians found in the wild in Ireland ? *(Warning: the name must match the latin name)*
# A=<input name="q4_amphibA_cname"/> : *Triturus* <input name="q4_amphibA_lname2"/> <span class="points">[2 points]</span>
# B=<input name="q4_amphibB_cname"/> : *Rana* <input name="q4_amphibB_lname2"/> <span class="points">[2 points]</span>
# C=<input name="q4_amphibC_cname"/> : *Bufo* <input name="q4_amphibC_lname2"/> <span class="points">[2 points]</span>
#
# * What proportion of Ireland's amphibian habitat have been lost over the past 100 years ? <span class="points">[1 point]</span>
# <input name="q4_amphib_irishhabitatlost_100years"/>%

# %% [markdown]
# ### Amphibian A
# * Up to what size can they grow ? <span class="points">[1 point]</span>
# <input name="q4_amphibA_maxsize"/> mm
#
# * List 2 criterias to distinguish males from females during their breeding season : <span class="points">[2 points]</span>
# <input name="q4_amphibA_malecriterion_A"/>
# <input name="q4_amphibA_malecriterion_B"/>
#
# * Give one of their Irish nickname : <span class="points">[1 point]</span>
# <input name="q4_amphibA_nickname"/>
#
# * When during the year do they emerge from winter torpor ? <span class="points">[1 point]</span>
# <input name="q4_amphibA_monthoutofwintertorpor"/>
#
# * How many eggs can a female lay in one breeding season ? <span class="points">[1 point]</span>
# <input name="q4_amphibA_eggsperfemaleperseason"/>
#
# * How long can amphibians A live ? <span class="points">[1 point]</span>
# <input name="q4_amphibA_lifeexpectancy_inyears"/> years
#
# * Identify amphibian A among the following photos : <span class="points">[4 points]</span>
# <table><tr>
# <th><input type=radio name="q4_amphibA_img_choice" value="A">![img_choice](http://upload.wikimedia.org/wikipedia/commons/2/2c/Triturus_dobrogicus_dunai_tarajosg%C5%91te.jpg "choice A")</input></th><th><input type=radio name="q4_amphibA_img_choice" value="B">![img_choice](http://darkwave.netgoth.org.uk/~caleb/pix/trikarm4a.jpg "choice B")</input></th>
# </tr><tr>
# <th><input type=radio name="q4_amphibA_img_choice" value="C">![img_choice](http://wdfw.wa.gov/ais/graphics/species_images/triturus_vulgaris_lantzi.jpg "choice C")</input></th><th><input type=radio name="q4_amphibA_img_choice" value="D">![img_choice](http://ecologist.co.uk/wp-content/uploads/2013/09/palmate-newt-001.jpg "choice D")</input></th>
# </tr></table>

# %% [markdown]
# ### Amphibian B
# * What is the size of an adult individual ? <span class="points">[1 point]</span>
# <input name="q4_amphibB_size"/> mm
#
# * When in the year is their breeding period ? <span class="points">[1 point]</span>
# <input name="q4_amphibB_breeding_period"/>
#
# * What is the name of the male breeding hold ? <span class="points">[1 point]</span>
# <input name="q4_amphibB_breeding_hold"/>
#
# * List three other animals that it eats : <span class="points">[3 points]</span>
# <input name="q4_amphibB_prey_A"/>
# <input name="q4_amphibB_prey_B"/>
# <input name="q4_amphibB_prey_C"/>
#
# * How long can amphibians A live ? <span class="points">[1 point]</span>
# <input name="q4_amphibB_lifeexpectancy_inyears"/> years
#
# * Identify amphibian B among the following photos : <span class="points">[2 points]</span>
# <table><tr>
# <th><input type=radio name="q4_amphibB_img_choice" value="A">![img_choice](http://people.mokk.bme.hu/~daniel/Heni/regebbi/041Amphibia/038%20%23%23%23%20erdei%20b%E9ka%20%28Rana%20dalmatina%29.jpg "choice A")</input></th><th><input type=radio name="q4_amphibB_img_choice" value="B">![img_choice](http://www.surrey-arg.org.uk/SARG/08000-TheAnimals/SpeciesPages/Common_Frog/Common_Frog_Typical.jpg "choice B")</input></th>
# </tr><tr>
# <th><input type=radio name="q4_amphibB_img_choice" value="C">![img_choice](http://upload.wikimedia.org/wikipedia/commons/d/d8/RanaArvalisFemale.jpg "choice C")</input></th><th><input type=radio name="q4_amphibB_img_choice" value="D">![img_choice](http://metadata.froghome.org/public/photos/13381944661ton-l.jpg "choice D")</input></th>
# </tr></table>

# %% [markdown]
# ### Amphibian C
# * What is the size of an adult individual ? <span class="points">[1 point]</span>
# <input name="q4_amphibC_size"/> mm
#
# * When in the year is their breeding period ? <span class="points">[1 point]</span>
# <input name="q4_amphibC_breeding_period"/>
#
# * In what shape are their eggs laid ? <span class="points">[1 point]</span>
# <input type=radio name="q4_amphibC_eggslaindinshape" value="ball">A ball</input>
# <input type=radio name="q4_amphibC_eggslaindinshape" value="creamedembryo">A creamed embryo</input>
# <input type=radio name="q4_amphibC_eggslaindinshape" value="string">A string</input>
# <input type=radio name="q4_amphibC_eggslaindinshape" value="thinsheet">A thin sheet</input>
#
# * How long last their metamorphose ? <span class="points">[1 point]</span>
# <input name="q4_amphibC_metamorphose_length"/> months
#
# * What is their defense mechanism ? <span class="points">[1 point]</span>
# <input name="q4_amphibC_defense_mechanism"/>
#
# * Identify amphibian C among the following photos : <span class="points">[4 points]</span>
# <table><tr>
# <th><input type=radio name="q4_amphibC_img_choice" value="A">![img_choice](http://163.238.8.180/~ruane/images/az%20nm/bufo%20cognatus.png "choice A")</input></th><th><input type=radio name="q4_amphibC_img_choice" value="B">![img_choice](http://upload.wikimedia.org/wikipedia/commons/f/fc/Bufo_boreas1.jpg "choice B")</input></th>
# </tr><tr>
# <th><input type=radio name="q4_amphibC_img_choice" value="C">![img_choice](http://images4.wikia.nocookie.net/__cb20130626051920/reptiles/images/1/16/Bufo_bufo_01.jpg "choice C")</input></th><th><input type=radio name="q4_amphibC_img_choice" value="D">![img_choice](http://www.denbighshirecountryside.org.uk/files/Natterjack%20Toad%20sam%20dyer.JPG "choice D")</input></th>
# </tr></table>

# %% [markdown]
# ## Lampreys
# * What do young lampreys eat ? <span class="points">[1 point]</span>
# <input name="q5_lampreys_young_eat"/>
#
# * How long last their juvenile stage ? <span class="points">[1 point]</span>
# <input name="q5_lampreys_juvenilestage_inyears"/> years
#
# * List 3 fishes on which lampreys feed : <span class="points">[3 points]</span>
# <input name="q5_lampreys_preyfish_A"/>
# <input name="q5_lampreys_preyfish_B"/>
# <input name="q5_lampreys_preyfish_C"/>
#
# * List 2 main threats that lampreys face : <span class="points">[2 points]</span>
# <input name="q5_lampreys_threat_A"/>
# <input name="q5_lampreys_threat_B"/>
#
# * The 3 Irish lamprey species :
#   * The smallest <input name="q5_lampreys_species_smallest_cname"/> (*Bonus latin name:* <input name="q5_lampreys_species_smallest_lname"/>) <span class="points">[1 point]</span>
#     * Size : <input name="q5_lampreys_species_smallest_size_incm"/> cm <span class="points">[1 point]</span>
#     * Spawning area temperature : <input name="q5_lampreys_species_smallest_spawningareatemperature"/>°C <span class="points">[1 point]</span>
#   * The biggest : <input name="q5_lampreys_species_biggest_cname"/> (*Bonus latin name:* <input name="q5_lampreys_species_biggest_lname"/>) <span class="points">[1 point]</span>
#     * Size : <input name="q5_lampreys_species_biggest_size_incm"/> cm <span class="points">[1 point]</span>
#     * Longest spawning migration known : <input name="q5_lampreys_species_biggest_longestmigration"/> km <span class="points">[1 point]</span>
#   * King killer <input name="q5_lampreys_species_kingkiller_cname"/> (*Bonus latin name:* <input name="q5_lampreys_species_kingkiller_lname"/>) <span class="points">[1 point]</span>
#     * Size : <input name="q5_lampreys_species_kingkiller_size_incm"/> cm <span class="points">[1 point]</span>
#     * Name of the king killed : <input name="q5_lampreys_species_kingkiller_kingname"/> <span class="points">[1 point]</span>

# %% [markdown]
# # Vocabulary

# %% [markdown]
# ## English to French
# **slough** : <input name="q0_voc_slough_mue"/>
# **fallow** : <input name="q0_voc_fallow_jachere"/>
# **aphid** : <input name="q0_voc_aphid_puceron"/>
# **blotch** : <input name="q0_voc_blocth_tache"/>
# **rudder** : <input name="q0_voc_rudder_gouvernail"/>
# **polecat** : <input name="q0_voc_polecat_putois"/>
# **wagtail** : <input name="q0_voc_wagtail_bergeronnette"/>
# **fen** : <input name="q0_voc_fen_marecage"/>
# **ramshorn snail** : <input name="q0_voc_ramshornsnail_planorbe"/>
# **three-spined stickleback** : <input name="q0_voc_threespinedstickleback_epinoche"/>

# %% [markdown]
# ## French to English
# <input name="q0_voc_sorrel_oseille"/> : *oseille*
# <input name="q0_voc_hawthorn_aubepine"/> : *aubépine*
# <input name="q0_voc_nightingale_rossignol"/> : *rossignol*
# <input name="q0_voc_vixen_renarde"/> : *renarde*
# <input name="q0_voc_puffin_macareux"/> : *macareux*
# <input name="q0_voc_reed_roseau"/> : *roseau*
# <input name="q0_voc_coaltit_mesangenoire"/> : *mésange noire*
# <input name="q0_voc_roach_gardon"/> : *gardon*
# <input name="q0_voc_elm_orme"/> : *orme*
# <input name="q0_voc_antler_ramure"/> : *ramure*
# <input name="q0_voc_willow_saule"/> : *saule*

# %% [markdown]
# <button type="button" onclick="save_inputs_to_file()">Submit</button>
